# %%
import pandas as pd
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# True

# %%
df = pd.read_csv("preprocessed_imdb.csv")
df.head()
# Out:
#                                               review sentiment  \
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
#
#                                           clean_text
# 0  reviewer mentioned oz episode youll hooked rig...
# 1  wonderful little production filming technique ...
# 2  thought wonderful way spend time hot summer we...
# 3  basically there family little boy jake think t...
# 4  petter matteis love time money visually stunni...

# %%
sid = SentimentIntensityAnalyzer()

# %%
def get_sentiment(text):
    score = sid.polarity_scores(text)['compound']
    
    if score >= 0.05:
        return "Positive"
    elif score <= -0.05:
        return "Negative"
    else:
        return "Neutral"

# %%
df['sentiment'] = df['clean_text'].apply(get_sentiment)
df[['clean_text', 'sentiment']].head(10)
# Out:
#                                           clean_text sentiment
# 0  reviewer mentioned oz episode youll hooked rig...  Negative
# 1  wonderful little production filming technique ...  Positive
# 2  thought wonderful way spend time hot summer we...  Positive
# 3  basically there family little boy jake think t...  Negative
# 4  petter matteis love time money visually stunni...  Positive
# 5  probably alltime favorite story selflessness s...  Positive
# 6  sure resurrection dated seahunt series tech to...  Positive
# 7  show amazing fresh innovative idea first aired...  Positive
# 8  encouraged positive comment looking forward ba...  Negative
# 9  original gut wrenching laughter young old love...  Positive

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# Positive    32340
# Negative    17057
# Neutral       603
# Name: count, dtype: int64
